# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {
    'Name': ['Alice', 'Bob', 'Charlie',"rose"],
    'Age': [35, 30, 25, 40],
    'City': ['NY', 'LA', 'UK', "Jupiter"]
}
df = pd.DataFrame(data)

print(df)
# Out:
#       Name  Age     City
# 0    Alice   35       NY
# 1      Bob   30       LA
# 2  Charlie   25       UK
# 3     rose   40  Jupiter

# %%
# 7.1 Multi-Indexing
df_multi = df.set_index(['City', 'Name'])
print(df_multi)

plt.plot(df["Name"],df["Age"])
plt.xlabel("Name")
plt.ylabel("Age")

plt.show()
# Out:
#                  Age
# City    Name
# NY      Alice     35
# LA      Bob       30
# UK      Charlie   25
# Jupiter rose      40
